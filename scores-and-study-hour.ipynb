# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df1 = pd.read_csv('/kaggle/input/student-study-hours/score.csv')

# %%
df2 = pd.read_csv('/kaggle/input/student-study-hours/score_updated.csv')

# %%
df2
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# ..    ...     ...
# 91    5.8      60
# 92    4.4      44
# 93    6.1      63
# 94    3.7      37
# 95    8.0      84
#
# [96 rows x 2 columns]

# %%
df2.isnull().sum()

# %%
import matplotlib.pyplot as plt

X = df2['Hours']
y = df2['Scores']

# Create a scatter plot
plt.scatter(X, y, label='Scatter Plot', color='blue', marker='o')

# Add labels and title
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Simple Scatter Plot')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
X

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y , test_size = .2,random_state = 2)

# %%
x_train

# %%
x_test

# %%
y_train

# %%
y_test

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Assuming x_train is a Pandas Series
x_train_reshaped = np.array(x_train).reshape(-1, 1)

# Create a Linear Regression model
lr = LinearRegression()

# Fit the model with the reshaped data
lr.fit(x_train_reshaped, y_train)

# %%
lr.predict(np.array(x_test).reshape(-1,1))

# %%
y_test

# %%
plt.scatter(df2['Hours'], df2['Scores'])

# Plot the regression line
x_line = np.linspace(min(df2['Hours']), max(df2['Hours']), 100).reshape(-1, 1)
y_line = lr.predict(x_line)
plt.plot(x_line, y_line, color='red', label='Regression Line')

plt.xlabel('Hours')
plt.ylabel('Scores')
plt.legend()
plt.show()

# %%
m = lr.coef_
m

# %%
b = lr.intercept_
b

# %%
# equation of best fit line is m*x + b
m*8 + b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # equation of best fit line is m*x + b
# ----> 2 m*8 + b
#
# NameError: name 'm' is not defined

# %%
m*1 + b
# Out:
# array([10.9397554])
